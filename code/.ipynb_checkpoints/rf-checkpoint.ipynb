# %% [markdown]
# # Packages, Data, Functions

# %%
# Import packages
import numpy as np
import skimage.io as skio
import skimage.morphology as skm
from skimage import feature
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# %%
# Read the data
rgb = skio.imread("../../data/MA_roads/tiff/train/10828735_15.tiff")
ans = skio.imread("../../data/MA_roads/tiff/train_labels/10828735_15.tif")

# Display training data and correct output
fig, ax = plt.subplots(1, 2, figsize = (10, 6))
skio.imshow(rgb, ax = ax[0])
ax[0].set_title("Data")
skio.imshow(ans, ax = ax[1])
ax[1].set_title("Solution");

# %%
# Function to print several accuracy metrics
def accuracy_metrics(y_true, y_pred):
    # Create confusion matrix
    C = confusion_matrix(y_true, y_pred)

    # Overall accuracy rate
    acc = (C[0,0] + C[1,1])/C.sum()

    # True positive rate
    tpr = (C[0,0])/(C[0,0] + C[0,1])
    
    # True negative rate
    tnr = (C[1,1])/(C[1,0] + C[1,1])

    # Print results
    print("Confusion matrix:\n", C)
    print("Overall accuracy:", np.round(acc, 3), "\nTrue positive rate (not road):", np.round(tpr, 3), "\nTrue negative rate (roads)", np.round(tnr, 3))

# %% [markdown]
# # Create Training and Testing Subsets

# %%
# Create training subset of data
# It takes too much computing power to run the model on the whole image on our own machines
small_rgb = rgb[0:400, 1200:, :]
small_ans = ans[0:400, 1200:]

fig, ax = plt.subplots(1, 2, figsize = (10, 6))
skio.imshow(small_rgb, ax = ax[0])
ax[0].set_title("Training Data")
skio.imshow(small_ans, ax = ax[1])
ax[1].set_title("Training Solution");

# %%
# Create testing subset of data
# It takes too much computing power to run the model on the whole image on our own machines
small_rgb_test = rgb[1200:, 0:400, :]
small_ans_test = ans[1200:, 0:400]

fig, ax = plt.subplots(1, 2, figsize = (10, 6))
skio.imshow(small_rgb_test, ax = ax[0])
ax[0].set_title("Testing Data")
skio.imshow(small_ans_test, ax = ax[1])
ax[1].set_title("Testing Solution");

# %% [markdown]
# # Random Forest Model: RGB
# ## Train model

# %%
# Flatten images
train_small_rgb = small_rgb.reshape(120000, 3)
y_train = small_ans.reshape(120000)

# %%
# Create model
RF = RandomForestClassifier()

# Fit and output the performance of the model
model1 = RF.fit(train_small_rgb, y_train)

# %%
# Predictions on training data
model1_pred = model1.predict(train_small_rgb)

# Confusion matrix
accuracy_metrics(y_train, model1_pred)
# Out:
# Confusion matrix:
#  [[105474   1503]
#  [  4075   8948]]
# Overall accuracy: 0.954
# True positive rate (not road): 0.986
# True negative rate (roads) 0.687

# %% [markdown]
# While we have a really good overall accuracy rate, we are correctly predicting only 68.7% of the road pixels.

# %%
# Convert predictions to image
train_preds = model1_pred.reshape(400, 300)

# Create figure
fig, ax = plt.subplots(1, 2, figsize = (10, 6))

skio.imshow(train_preds, ax = ax[0])
ax[0].set_title("Predicted Labels")

skio.imshow(small_ans, ax = ax[1])
ax[1].set_title("Actual Solution");

# %% [markdown]
# Visually, our solution looks alright, but it obviously has room for improvement.
# Let's see what our results look like on the testing data.

# %% [markdown]
# ## Test model

# %%
# Flatten images
test_small_rgb = small_rgb_test.reshape(120000, 3)
y_test = small_ans_test.reshape(120000)

# %%
# Predictions on testing data
model1_test_pred = model1.predict(test_small_rgb)

# Confusion matrix
accuracy_metrics(y_test, model1_test_pred)
# Out:
# Confusion matrix:
#  [[108164   4733]
#  [  6495    608]]
# Overall accuracy: 0.906
# True positive rate (not road): 0.958
# True negative rate (roads) 0.086

# %% [markdown]
# While we still have a good overall accuracy rate but, our predictions of roads is substantially worse.
# We have only classified 8.3% of the road pixels correctly.

# %%
# Convert predictions to image
test_preds = model1_test_pred.reshape(300, 400)

# Create figure
fig, ax = plt.subplots(1, 2, figsize = (10, 6))

skio.imshow(test_preds, ax = ax[0])
ax[0].set_title("Predicted Labels")

skio.imshow(small_ans_test, ax = ax[1])
ax[1].set_title("Actual Solution");

# %% [markdown]
# Our model did NOT generalize well! This looks terrible!

# %% [markdown]
# # Incorporating Canny Edge Detection and K-Means Clustering
#
# ## Canny Edge Detection

# %%
# Canny edge detection
canny_edges_r = feature.canny(small_rgb[:,:,0], sigma=4);
canny_edges_g = feature.canny(small_rgb[:,:,1], sigma=4);
canny_edges_b = feature.canny(small_rgb[:,:,2], sigma=4);

# Create figure
fig, ax = plt.subplots(1, 3, figsize = (10, 5))
skio.imshow(canny_edges_r, ax = ax[0])
ax[0].set_title("Canny Edges Red")
skio.imshow(canny_edges_g, ax = ax[1])
ax[1].set_title("Canny Edges Green")
skio.imshow(canny_edges_b, ax = ax[2])
ax[2].set_title("Canny Edges Blue");

# %% [markdown]
# They all basically look the same!
# let's sum them together and use the result as one channel in the input to our model.

# %%
# Sum edges together
canny_edges = (canny_edges_r + canny_edges_g + canny_edges_b)

# Create figure
fig, ax = plt.subplots(1, 2, figsize = (10, 6))
skio.imshow(canny_edges, ax = ax[0])
ax[0].set_title("Canny Edges")
skio.imshow(small_rgb, ax = ax[1])
ax[1].set_title("Actual Image");

# %%
# Create disk
disk = skm.disk(1)

# Area closing
closed_edges = skm.dilation(canny_edges, footprint = disk)

# Create figure
fig, ax = plt.subplots(1, 3, figsize = (10, 6))
skio.imshow(canny_edges, ax = ax[0])
ax[0].set_title("Canny Edges")
skio.imshow(closed_edges, ax = ax[1])
ax[1].set_title("Closed Edges")
skio.imshow(small_ans, ax = ax[2])
ax[2].set_title("Training Solution");

# %% [markdown]
# ## K-Means Clustering

# %%
# Add edges as a channel
small_rgb_canny = np.dstack((small_rgb, closed_edges.astype(np.uint8) * 255))

# K-means clustering
feature_vals = small_rgb_canny.reshape((-1,4))
feature_vals = np.float32(feature_vals)

sk_kmeans = KMeans(n_clusters=7, verbose=1).fit(feature_vals)

sk_segmented_image = sk_kmeans.labels_.reshape((small_rgb.shape[0], small_rgb.shape[1]))
# Out:
# Initialization complete
# Iteration 0, inertia 159314800.0.
# Iteration 1, inertia 111493312.0.
# Iteration 2, inertia 107643648.0.
# Iteration 3, inertia 105398352.0.
# Iteration 4, inertia 103871696.0.
# Iteration 5, inertia 102844584.0.
# Iteration 6, inertia 102132880.0.
# Iteration 7, inertia 101663728.0.
# Iteration 8, inertia 101334632.0.
# Iteration 9, inertia 101092608.0.
# Iteration 10, inertia 100915712.0.
# Iteration 11, inertia 100782672.0.
# Iteration 12, inertia 100684376.0.
# Iteration 13, inertia 100614912.0.
# Iteration 14, inertia 100564304.0.
# Iteration 15, inertia 100529424.0.
# Iteration 16, inertia 100501712.0.
# Iteration 17, inertia 100482936.0.
# Converged at iteration 17: center shift 0.2642844617366791 within tolerance 0.39252978515625003.

# %%
# Plot resulting layer
fig, ax = plt.subplots(1, 2, figsize = (10, 6))
skio.imshow(sk_segmented_image, cmap='gray', ax = ax[0])
ax[0].set_title("K-means layer");
skio.imshow(small_ans, ax = ax[1])
ax[1].set_title("Training Solution");
# Out:
# /Users/liamsmith/opt/anaconda3/envs/csci0452/lib/python3.12/site-packages/skimage/io/_plugins/matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# ## Train Model

# %%
# Add k-means as a layer
small_rgb_kmeans = np.dstack((small_rgb, sk_segmented_image.astype(np.uint8) * 255))

# %%
# Train model

# Flatten image
train_small_rgbk = small_rgb_kmeans.reshape(120000, 4)

# Create model
RF = RandomForestClassifier()

# Fit and output the performance of the model
model2 = RF.fit(train_small_rgbk, y_train)

# Predictions on training data
model2_pred = model2.predict(train_small_rgbk)

# Confusion matrix
accuracy_metrics(y_train, model2_pred)
# Out:
# Confusion matrix:
#  [[105635   1342]
#  [  3290   9733]]
# Overall accuracy: 0.961
# True positive rate (not road): 0.987
# True negative rate (roads) 0.747

# %% [markdown]
# Before adding the k-means from Canny edge detection layer to our training data, our overall accuracy was 0.954, true positive rate (not road) was 0.986, and true negative rate (roads) was 0.687.
# Our current results represent a negligible improvement in the overall accuracy and non-road predictions, but a substantial improvement in the road predictions, which was our main concern.
# Let's look at an image representation of our results.

# %%
# Convert predictions to image
train_preds = model2_pred.reshape(400, 300)

# Create figure
fig, ax = plt.subplots(1, 2, figsize = (10, 6))

skio.imshow(train_preds, ax = ax[0])
ax[0].set_title("Predicted Labels")

skio.imshow(small_ans, ax = ax[1])
ax[1].set_title("Actual Solution");

# %% [markdown]
# Again, this looks relatively good, but we are curious about the results on testing data!

# %% [markdown]
# ### Prepare Test Data

# %%
# Canny edge detection
canny_edges_rt = feature.canny(small_rgb_test[:,:,0], sigma=4);
canny_edges_gt = feature.canny(small_rgb_test[:,:,1], sigma=4);
canny_edges_bt = feature.canny(small_rgb_test[:,:,2], sigma=4);

# Create figure
fig, ax = plt.subplots(1, 3, figsize = (10, 5))
skio.imshow(canny_edges_rt, ax = ax[0])
ax[0].set_title("Canny Edges Red")
skio.imshow(canny_edges_gt, ax = ax[1])
ax[1].set_title("Canny Edges Green")
skio.imshow(canny_edges_bt, ax = ax[2])
ax[2].set_title("Canny Edges Blue");

# %%
# Sum edges together
canny_edgest = (canny_edges_rt + canny_edges_gt + canny_edges_bt)

# Create figure
fig, ax = plt.subplots(1, 2, figsize = (10, 6))
skio.imshow(canny_edgest, ax = ax[0])
ax[0].set_title("Canny Edges")
skio.imshow(small_rgb_test, ax = ax[1])
ax[1].set_title("Actual Image");

# %%
# Area closing
closed_edgest = skm.dilation(canny_edgest, footprint = disk)

# Create figure
fig, ax = plt.subplots(1, 3, figsize = (10, 6))
skio.imshow(canny_edgest, ax = ax[0])
ax[0].set_title("Canny Edges")
skio.imshow(closed_edgest, ax = ax[1])
ax[1].set_title("Closed Edges")
skio.imshow(small_ans_test, ax = ax[2])
ax[2].set_title("Testing Solution");

# %%
# Add edges as a channel
small_rgb_cannyt = np.dstack((small_rgb_test, closed_edgest.astype(np.uint8) * 255))

# %%
# K-means clustering
feature_valst = small_rgb_cannyt.reshape((-1,4))
feature_valst = np.float32(feature_valst)

sk_kmeanst = KMeans(n_clusters=7, verbose=1).fit(feature_valst)

sk_segmented_imaget = sk_kmeanst.labels_.reshape((small_rgb_test.shape[0], small_rgb_test.shape[1]))
# Out:
# Initialization complete
# Iteration 0, inertia 153699392.0.
# Iteration 1, inertia 124677840.0.
# Iteration 2, inertia 123573952.0.
# Iteration 3, inertia 123075872.0.
# Iteration 4, inertia 122838352.0.
# Iteration 5, inertia 122687072.0.
# Iteration 6, inertia 122582520.0.
# Iteration 7, inertia 122520088.0.
# Iteration 8, inertia 122472224.0.
# Iteration 9, inertia 122435912.0.
# Iteration 10, inertia 122406712.0.
# Iteration 11, inertia 122377872.0.
# Iteration 12, inertia 122357864.0.
# Converged at iteration 12: center shift 0.47688791155815125 within tolerance 0.512282470703125.

# %%
# Plot resulting layer
fig, ax = plt.subplots(1, 2, figsize = (10, 6))
skio.imshow(sk_segmented_imaget, cmap='gray', ax = ax[0])
ax[0].set_title("K-means layer");
skio.imshow(small_ans_test, ax = ax[1])
ax[1].set_title("Testing Solution");
# Out:
# /Users/liamsmith/opt/anaconda3/envs/csci0452/lib/python3.12/site-packages/skimage/io/_plugins/matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# ## Test Model

# %%
# Add k-means as a layer
small_rgb_kmeanst = np.dstack((small_rgb_test, sk_segmented_imaget.astype(np.uint8) * 255))

# Flatten image
test_small_rgbk = small_rgb_kmeanst.reshape(120000, 4)

# Predictions on testing data
model2_test_pred = model2.predict(test_small_rgbk)

# Confusion matrix
accuracy_metrics(y_test, model2_test_pred)
# Out:
# Confusion matrix:
#  [[111249   1648]
#  [  6871    232]]
# Overall accuracy: 0.929
# True positive rate (not road): 0.985
# True negative rate (roads) 0.033

# %% [markdown]
# Adding the k-means metric to our model had negligible impact on our results.
# It improved the accuracy from 0.906 to 0.929, the true positive rate (not road) from 0.958 to 0.985, but decreased the true negative rate (roads) from 0.086 to 0.033, which is what we were really hoping to improve.
# We think this occured because K-means is an unsupervised clustering technique.
# There is not necessarily any correlation between the group labels in the training image's k-means clustering and the group labels in the testing image's k-means clustering.
# For example, a 2 could represent road pixels in the training version, but a 5 could represent road pixels in the testing version.
